# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\ADMIN\OneDrive\Documents\Downloads\New folder\Cars93.csv")
df.describe()
# maximumweight=df['Weight'].max()
df.shape
# Out:
# (93, 28)

# %%
# Find out cars with price is greater than average price
aboveavg=df[(df['Price'])>(df['Price'].mean()) ]
aboveavg.sort_values(by='Price')
# a=aboveavg
# a.min()
# df['Price'].mean()
# Out:
#     id   Manufacturer           Model     Type  Min.Price  Price  Max.Price  \
# 88  89     Volkswagen         Eurovan      Van       16.6   19.7       22.7
# 40  41          Honda         Prelude   Sporty       17.0   19.8       22.7
# 35  36           Ford        Aerostar      Van       14.5   19.9       25.3
# 89  90     Volkswagen          Passat  Compact       17.6   20.0       22.4
# 36  37           Ford          Taurus  Midsize       15.6   20.2       24.8
# 70  71     Oldsmobile    Eighty-Eight    Large       19.5   20.7       21.9
# 6    7          Buick         LeSabre    Large       19.9   20.8       21.7
# 37  38           Ford  Crown_Victoria    Large       20.1   20.9       21.7
# 66  67         Nissan          Maxima  Midsize       21.0   21.5       22.0
# 91  92          Volvo             240  Compact       21.8   22.7       23.5
# 86  87         Toyota          Previa      Van       18.9   22.7       26.6
# ...

# %%
 # Find out the car with maximum weight and which is compact type


df['Type'].value_counts()
cd=df[df['Type']=='Compact']
cd.sort_values(by='Weight')
maxweight=cd['Weight'].max()

# %%
# ➢Find out the car with maximum price and belongs to Van Type

abc=df[df['Type']=='Van']
# df['Type'].value_counts()
# abc.sort_values(by='Price')
maxpricevan=abc['Price'].max()

# %%
# Find out the car with cheapest price and which belongs to compact category and has no 
# Airbags
compact=df[df['Type']=='Compact']
compact
noairb=compact[compact['AirBags'].isna() ]
# x['Price'].min()
x
# x=compact[compact['AirBags']== 'Driver only']
# x['Price'].min()
# compact.info()
# x=compact[compact['AirBags']=='Driver only']
# x=compact[compact['AirBags']=='Driver & Passenger']
noairbagminprice=noairb['Price'].min()

# %%
maximumweight=df['Weight'].max()  
aboveavg=df[(df['Price'])>(df['Price'].mean()) ]  #carabove mean average
maxweight  #compact
maxpricevan
noairbagminprice
# Out:
# 11.1
